# %%
from pycocotools.coco import COCO
import os
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import PIL
import torch
import sys
import os
import cv2
import argparse
import matplotlib.pyplot as plt
import torchvision.transforms as T

from PIL import Image
from matplotlib.colors import rgb_to_hsv, hsv_to_rgb

from classifier import multilabel_classifier
from load_data import *

###                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
# Referenced from:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# https://github.com/jacobgil/pytorch-grad-cam/blob/master/gradcam.py                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# Example usage:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           
# python get_cams.py --modelpath $MODELPATH --img_ids 535811 430054 554674                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# --modelpath: path to the model to visualize                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
# --img_ids: COCOStuff image IDs (use the Explore tool on the COCO dataset website)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
###                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        

def get_heatmap(CAM_map, img):
    CAM_map = cv2.resize(CAM_map, (img.shape[0], img.shape[1]))
    CAM_map = CAM_map - np.min(CAM_map)
    CAM_map = CAM_map / np.max(CAM_map)
    CAM_map = 1.0 - CAM_map # make sure colormap is not reversed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           
    heatmap = cv2.applyColorMap(np.uint8(255 * CAM_map), cv2.COLORMAP_JET)
    heatmap = np.float32(heatmap) / 255
    #heatmap = heatmap + np.float32(img)
    heatmap = heatmap / np.max(heatmap)
    heatmap = np.uint8(255 * heatmap)
    
    lb = (85, 90, 100) 
    ub = (130, 255, 255)
#     lb2 = (175, 50, 20)
#     ub2 = (180, 255, 255)
    
    # Do the contour detection on the input frame
    hsv = cv2.cvtColor(heatmap, cv2.COLOR_BGR2HSV)

    # Compute
#     mask1 = cv2.inRange(hsv, lb, ub)
#     mask2 = cv2.inRange(hsv, lb2, ub2)
#     mask = cv2.bitwise_or(mask1, mask2)
    
    mask = cv2.inRange(hsv, lb, ub)
    heatmap=mask
    
    
    return heatmap

def returnCAM(feature_conv, weight_softmax, class_labels, device):
    bz, nc, h, w = feature_conv.shape # (1, hidden_size, height, width)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
    output_cam = torch.Tensor(0, 7, 7).to(device=device)
    for idx in class_labels:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
        cam = torch.mm(weight_softmax.unsqueeze(0), feature_conv.reshape((nc, h*w)))
        cam = cam.reshape(h, w)
        cam = cam - cam.min()
        cam_img = cam / cam.max()
        output_cam = torch.cat([output_cam, cam_img.unsqueeze(0)], dim=0)
    return output_cam

def returnCAM_featuresplit(feature_conv, weight_softmax, class_labels, device, split=1024):
    feature_conv_o = feature_conv[:,:split,:,:]
    feature_conv_s = feature_conv[:,split:,:,:]
    bz, nc, h, w = feature_conv.shape
    output_cam = torch.Tensor(0, 7, 7).to(device=device)
    for idx in class_labels:
        cam_o = torch.mm(weight_softmax[idx][:split].unsqueeze(0), feature_conv_o.reshape((split, h*w)))
        cam_s = torch.mm(weight_softmax[idx][split:].unsqueeze(0), feature_conv_s.reshape((nc-split, h*w)))
        cam_o = cam_o.reshape(h, w)
        cam_s = cam_s.reshape(h, w)
        cam_o = cam_o - cam_o.min()
        cam_s = cam_s - cam_s.min()
        cam_o_img = cam_o / cam_o.max()
        cam_s_img = cam_s / cam_s.max()
        output_cam = torch.cat([output_cam, cam_o_img.unsqueeze(0), cam_s_img.unsqueeze(0)], dim=0)
    return output_cam

# %%
# parser = argparse.ArgumentParser()
# parser.add_argument('--modelpath', type=str, default=None)
# parser.add_argument('--img_ids', type=int, nargs='+', default=0)
# parser.add_argument('--outdir', type=str, default=None)
# parser.add_argument('--featuresplit', default=False, action="store_true")
# parser.add_argument('--split', type=int, default=1024)
# parser.add_argument('--coco2014_images', type=str, default='/n/fs/visualai-scr/Data/Coco/2014data')
# parser.add_argument('--device', default=torch.device('cuda'))
# parser.add_argument('--dtype', default=torch.float32)
# arg = vars(parser.parse_args())
arg = {'modelpath': '/n/fs/context-scr/nmeister/genderbias/models_new/224/lr_0.0001_wd_0.0/model_199.pth', 
       # female not top 10
       'img_ids':  [373424, 297180, 3761, 416851, 133690, 541108, 16308, 32932, 386035, 446812, 89078, 416660, 147448, 350231, 516875, 351868, 186038, 62692, 300791, 395665, 445597, 279984, 508006, 279490, 297669, 407286, 391090, 384136, 201305, 284542, 554500, 1757, 428140, 321390, 44476, 300142, 459265, 303926, 97809, 457249, 356827, 312421, 31981, 163746, 499866, 37988, 48320, 164366, 182681, 552504, 457003, 431177, 255322, 7050, 364031, 169500, 135483, 343453, 507833, 170716, 229286, 36561, 259761, 100624, 522889, 89814, 320106, 580847, 40821, 218060, 46497, 537991, 303219, 325907, 393068, 185890, 478420, 456127, 366679, 120783, 548223, 114389, 81827, 304180, 92985, 443969, 13639, 336053, 419386, 210857, 311300, 193968, 278323, 140983, 422755, 156375, 484978, 489763, 53183, 427612, 321476, 479126, 536000, 557596, 4554, 487498, 489407, 202001, 138075, 445999, 414170, 433980, 134552, 194716, 41899, 25228, 487575, 542634, 300323, 347390, 558458, 227204, 117197, 548703, 161032, 526222, 278365, 334021, 519706, 520430, 310442, 192858, 382737, 70739, 316254, 264948, 385377, 415153, 410339, 124873, 374982, 221864, 452767, 331875, 393743, 280888, 230646, 283947, 231855, 248761, 79189, 185156, 157220, 577277, 563615, 161925, 323561, 16285, 463398, 84533, 52936, 580778, 191342, 475725, 507273, 200572, 558661, 168583, 277020, 443835, 15140, 428754, 193674, 82940, 142108, 524665, 338384, 446990, 18928, 233915, 377984, 333020, 547258, 179571, 230468, 526000, 383419, 248069, 327617, 473237, 63939, 399462, 235808, 266889, 3934, 488500, 261587, 516416, 376891, 276055, 348973, 37865, 342204, 135756, 266768, 455355, 351489, 280909, 545735, 191577, 549797, 267315, 198448, 3786, 143119, 167724, 441511, 407644, 29045, 496718, 389273, 21924, 332844, 114710, 143926, 295957, 419190, 412247, 27731, 556862, 530061, 367804, 564612, 505471, 447787, 381608, 367818, 533976, 18563, 359947, 204059, 281759, 470536, 365851, 178753, 54654, 237428, 453001, 496239, 124629, 470545, 191721, 550117, 419158, 513965, 71072, 175908, 385320, 225963, 190372, 47739, 227491, 434657, 223362, 154644, 462345, 510548, 209995, 506874, 144243, 355179, 562885, 421915, 350002, 87864, 58350, 413634, 543193, 187658, 519688, 301266, 362869, 1296, 531967, 162530, 75187, 580108, 73753, 26560, 399415, 246968, 456662, 335532, 242724, 253986, 254164, 19032, 47624, 490923, 385861, 107729, 213247, 262235, 192838, 170173, 59207, 267314, 576629, 542758, 24243, 61747, 139856, 328728, 376247, 555669, 562150, 508339, 470604, 30066, 375021, 230245, 494014, 402233, 520778, 490582, 402823, 149592, 397225, 29934, 132544, 168781, 437351, 177934, 392022, 65736, 285291, 45627, 407602, 431173, 9813, 439902, 253960, 117744, 511463, 449522, 437325, 232610, 132554, 515485, 263613, 231879, 294621, 371289, 147482, 419453, 31164, 45835, 252091, 390585, 84866, 169547, 233124, 27221, 64462, 96785, 169198, 487435, 548337, 580294, 405444, 693, 96215, 182025, 194158, 366031, 48684, 553869, 386879, 22801, 80306, 200471, 264568, 487418, 533449, 530934, 496548, 212558, 172946, 249687, 344005, 363036, 8690, 383838, 522425, 195842, 58425, 309418, 122678, 66336, 114183, 549713, 516345, 486175, 321968, 373344, 406147, 126512, 113159, 355197, 425136, 337264, 32081, 4980, 198489, 273967, 265125, 503755, 215787, 359589, 536653, 502570, 213421, 569314, 66502, 528046, 161781, 151965, 246746, 187743, 265777, 37158, 561539, 410337, 1180, 217522, 306670, 289900, 113037, 511669, 358572],
       # male not top 10
       # 'img_ids': [129706, 457718, 90351, 425870, 268620, 159215, 234031, 63549, 370839, 488571, 163575, 426635, 523873, 6593, 381332, 388531, 147154, 185768, 391199, 404464, 410272, 336431, 142564, 223746, 232241, 514990, 447736, 160652, 562632, 492282, 197398, 286556, 272048, 183970, 285661, 498940, 150872, 200745, 302292, 75655, 301317, 223188, 208778, 123125, 113951, 349611, 197847, 286523, 38693, 335644, 342051, 317595, 560439, 25005, 498061, 141426, 201426, 447242, 552573, 4243, 253746, 326702, 191842, 402115, 406555, 343038, 233238, 306749, 281111, 39368, 64474, 397705, 546222, 26967, 264155, 368752, 464476, 374702, 486986, 435820, 243912, 367116, 355974, 164250, 358149, 531510, 5670, 120420, 239202, 484145, 250335, 481819, 433370, 413900, 561795, 157469, 494328, 520289, 139512, 132644, 424247, 500716, 193622, 70945, 22371, 465453, 112568, 318888, 55950, 507167, 494608, 200047, 304390, 142620, 451751, 373075, 203372, 232488, 420775, 347982, 144273, 488823, 400794, 566941, 522235, 293548, 239130, 138115, 116017, 315899, 399830, 373577, 473869, 357542, 15663, 416700, 272440, 383703, 144438, 479597, 446209, 450686, 552775, 385580, 277533, 358055, 322163, 242610, 231795, 191112, 423694, 280022, 324322, 414212, 363119, 38726, 241, 274917, 40275, 502848, 326774, 494782, 299000, 17311, 481212, 147897, 578237, 330348, 170000, 338, 431691, 382999, 575595, 358884, 418292, 289388, 568560, 158945, 296459, 99615, 346589, 108965, 62549, 233483, 194138, 42752, 436791, 521419, 469793, 171762, 550995, 444895, 567812, 185925, 39951, 76161, 101913, 166918, 273825, 252383, 41875, 440189, 502113, 280705, 575964, 242051, 191687, 284341, 315037, 381430, 507180, 93437, 147958, 246053, 313627, 565374, 310998, 529447, 284445, 371129, 444304, 164835, 295656, 163782, 499884, 43882, 532735, 2142, 218093, 62858, 445944, 290839, 267169, 80613, 487720, 400317, 254807, 334332, 130586, 375063, 256940, 573571, 440034, 477010, 423773, 550601, 414516, 19667, 120792, 147806, 8594, 463653, 506561, 83110, 516239, 448181, 571718, 49893, 71738, 352011, 152012, 506458, 450400, 195281, 284064, 141509, 395, 409331, 425462, 424378, 281500, 391642, 261732, 554392, 496897, 30403, 122281, 354460, 143143, 294350, 434494, 369310, 569274, 562994, 233305, 378334, 281733, 150639, 259056, 567536, 442875, 151704, 387362, 137954, 60548, 63595, 144379, 484028, 128372, 458727, 138175, 516677, 86249, 11291, 409211, 252745, 395388, 428241, 357586, 353317, 391933, 270097, 42790, 247782, 382411, 392981, 69827, 463557, 73536, 145378, 199989, 530439, 362716, 216417, 94865, 423204, 335587, 316123, 302380, 479248, 127451, 95295, 99218, 306247, 11115, 420825, 104495, 332845, 155912, 559364, 488251, 24931, 344268, 563574, 252833, 359270, 345288, 435562, 194012, 385359, 566908, 579760, 79261, 126631, 27789, 450399, 340841, 335631, 268670, 519208, 245313, 264535, 402405, 213728, 61101, 537027, 89027, 315603, 231568, 151877, 76034, 184405, 516893, 215982, 303089, 55017, 63525, 229960, 145751, 13081, 554433, 73533, 401901, 298405, 247625, 209530, 350160, 256260, 300341, 526576, 176257, 65394, 565941, 561589, 92335, 109092, 579666, 474609, 337827, 126833, 448175, 548942, 366111, 490279, 105961, 373713, 262738, 177990, 239656, 103692, 527573, 80895, 52803, 494273, 409030, 581632, 224702, 398742, 235541, 47191, 292446, 296255, 463217, 242945, 438861, 124442, 243171, 178587, 208560, 147729, 555461, 146315, 414034, 246064, 361551, 386559, 245182, 157657, 428161, 47819, 400117, 560373, 103705, 222628, 341469, 551849, 204525, 235836, 98280, 37945, 260150, 345356, 166344, 94846, 186705, 385454, 135497, 8647, 518133, 186218, 68646, 131661, 358399, 135356, 526021, 444028, 547224, 319432, 326086, 53642, 84694, 43098, 427823, 436722, 538454, 204051, 122199, 566282, 156045, 378894, 206859, 352302, 414698, 566276, 113757, 42482, 201141, 24391, 53800, 134285, 105945, 441028, 67412, 237071, 378169, 431404, 382125, 476298, 74478, 50025, 534787, 486171, 487692, 126098, 73153, 126123, 163057, 403937, 391140, 195275, 136770, 99067, 121716, 352007, 292485, 415135, 258322, 340922, 149780, 551963, 203479, 248445, 493641, 53626, 73209, 295412, 546444, 444142, 367429, 180366, 544522, 566757, 523454, 512116, 142687, 188183, 2562, 374052, 79396, 46440, 433984, 359238, 156104, 191225, 284465, 32708, 150117, 225405, 543531, 538859, 524459, 12085, 223182, 269121, 5124, 5879, 548843, 558635, 116046, 195798, 16775, 149676, 211825, 134555, 412798, 290115, 310797, 34015, 433103, 441472, 335981, 549361, 408469, 189103, 367891, 261096, 490405, 146487, 432796, 5001, 198163, 310008, 356280, 218430, 85434, 274083, 308506, 89839, 501665, 546983, 423919, 120061, 109370, 188386, 39211, 322482, 20935, 323496, 292685, 370285, 261318, 433574, 479950, 18462, 335288, 478621, 465199, 79113, 420181, 275117, 18150, 172648, 20965, 449981, 206591, 485027, 471004, 571564, 358058, 489798, 61233, 368820, 18957, 565957, 110618, 13943, 315696, 284991, 133291, 248129, 228135, 361027, 302512, 490051, 185936, 472067, 571384, 17273, 449156, 341921, 397279, 25560, 486355, 356632, 459, 284143, 349676, 267684, 503202, 388100, 23359, 224757, 441862, 263163, 527029, 506515, 214274, 61414, 448113, 155319, 268044, 68546, 221390, 464751, 31442, 24869, 392781, 29030, 346185, 186977, 276552, 203629, 360600, 552532, 50942, 312889, 427135, 298578, 52087, 352127, 39844, 120070, 156076, 433822, 139457, 171622, 521956, 170640, 462929, 456525, 103509, 441518, 115521, 8495, 575487, 574141, 235093, 550423, 368222, 292529, 502402, 440529, 422200, 419789, 278359, 331138, 229184, 310310, 164883, 384808, 58869, 372024, 425964, 533407, 581496, 180764, 396496, 573930, 341828, 499255, 8771, 493196, 342593, 553669, 109673, 513692, 523244, 512451, 390435, 558137, 341017, 575637, 181446, 517135, 43133, 210299, 419235, 67975, 106849, 47498, 73009, 492677, 276893, 3590, 117563, 121031, 60700, 575088, 161877, 104486, 442387, 147471, 241187, 130838, 101622, 369373, 467000, 528729, 346965, 434958, 508167, 58043, 415183, 196815, 367929, 42399, 275111, 331883, 421360, 88854, 193605, 291256, 575882, 503663, 101636, 426342, 576857, 308487, 428554, 146963, 352684, 19491, 362348, 295593, 415885, 103431, 504452, 331777, 95051, 205720, 424225, 416795, 462784, 47837, 21604, 95702, 505818, 463690, 557812, 232845, 393710, 560677, 365317, 323442, 10142, 102872, 209773, 203466, 206036, 281766, 194499, 372577, 361147, 334511, 49648, 359356, 371216, 371503, 40341, 529917, 164440, 87070, 73199, 198530, 564511, 376372, 170178, 171805, 143931, 289323, 35279, 561062, 574297, 363594, 295491, 163025, 515850, 478664, 497674, 38586, 91994, 378667, 396350, 294182, 463918, 72582, 454495, 4312, 333402, 234230, 221291, 76176, 257656, 347144, 308759, 280623],
       # male top 10 
       # 'img_ids': [162774, 239327, 443426, 38601, 561336, 436582, 315705, 165638, 342302, 338948, 8443, 191672, 420411, 434689, 379841, 42190, 507015, 507187, 409221, 215633, 203669, 13465, 506471, 537069, 78638, 441586, 484279, 221555, 363902, 196490, 357529, 185479, 500657, 177149, 557595, 46329, 436323, 559160, 292236, 325602, 457754, 559547, 449895, 313718, 209904, 293888, 187795, 136915, 243989, 393809, 277945, 133556, 559685, 542938, 141779, 332221, 233348, 13201, 170048, 259690, 183176, 394033, 151159, 453216, 443713, 109454, 507927, 477655, 473839, 408288, 64189, 406734, 52314, 295006, 378970, 552188, 4021, 185850, 97580, 549055, 143582, 12047, 375324, 88455, 344832, 456184, 557830, 303768, 494555, 433787, 139163, 420357, 408818, 560902, 280008, 319073, 209162, 265725, 437540, 440093, 571029, 33815, 356421, 474054, 61605, 360851, 62023, 492814, 172439, 403150, 531061, 262175, 291572, 415073, 244151, 171241, 67310, 474, 448263, 447237, 377352, 219393, 273232, 363181, 75884, 1000, 423113, 369249, 511117, 486079, 292456, 244303, 439868, 85527, 151629, 235082, 414576, 254638, 153864, 230360, 143554, 295451, 80429, 379542, 51605, 331250, 445014, 147769, 329258, 432239, 157352, 182334, 424246, 489799, 417632, 310705, 369840, 4765, 16491, 232592, 380516, 297522, 457884, 564276, 296524, 421833, 550980, 539529, 47687, 445041, 175825, 484331, 436218, 237487, 130579, 165353, 304217, 369763, 492444, 166205, 7333, 57827, 327005, 455666, 415001, 409667, 523957, 170852, 525908, 414709, 544278, 97946, 447762, 538858, 302067, 338041, 95770, 253518, 256743, 577870, 60989, 541744, 515391, 121673, 113756, 446461, 368576, 175356, 305004, 382462, 462324, 240295, 127068, 405062, 241373, 22085, 362122, 206433, 529166, 493864, 305206, 110551, 485480, 434886, 244455, 4736, 10966, 273321, 413043, 181013, 226197, 376545, 313735, 19446, 525381, 350663, 19904, 187362, 205670, 62297, 104406, 303538, 118965, 219622, 173334, 181303, 268541, 429726, 102517, 489304, 236025, 83408, 402711, 27642, 429633, 382557, 475184, 476258, 486834, 214961, 501005, 449921, 297244, 358596, 403672, 167110, 413955, 571931, 267411, 420069, 103815, 216910, 462376, 456725, 349622, 258850, 74124, 124617, 190097, 234572, 328026, 575187, 175737, 534605, 423668, 170208, 279013, 347772, 523953, 509695, 163562, 484414, 441363, 10698, 248224, 66190, 365701, 138937, 355569, 14135, 83925, 440959, 84258, 473323, 215151, 570866, 47516, 487181, 37003, 71573, 362563, 300962, 87393, 45175, 417332, 216761, 574823, 422677, 227230, 62355, 285751, 581422, 89378, 9450, 472860, 478723, 309859, 362545, 98717, 13177, 419790, 516415, 111874, 10764, 557459, 31817, 349559, 227882, 46331, 502358, 443844, 215897, 422640, 34234, 195896, 138096, 510527, 63488, 457254, 199962, 535668, 230008, 231691, 44244, 88412, 474465, 20342, 454457, 557396, 277761, 240274, 568213, 171382, 190756, 76547, 531234, 263068, 455675, 467435, 375490, 338207, 297610, 289640, 200567, 432820, 68205, 151781, 210915, 144252, 121897, 465588, 168334, 33759, 42288, 169436, 26413, 284379, 147386, 328238, 177938, 521131, 7977, 68387, 205134, 15303, 243980, 548361, 181296, 164469, 52066, 50434, 32777, 428, 264424, 563849, 300214, 281829, 488463, 407443, 282830, 450993, 301797, 474741, 237628, 427160, 226020, 229358, 95417, 478522, 388654, 357737, 572233, 188296, 67078, 336949, 461491, 254535, 569972, 281409, 371309, 179950, 10442, 403078, 185444, 54527, 324158, 125051, 140068, 481064, 334178, 404607, 471087, 186226, 359232, 579192, 132615, 107964, 16497, 447088, 405223, 522612, 574977, 160669, 20179, 271666, 10779, 53754, 357383, 442861, 521994, 558229, 299734, 523517, 25096, 469840, 468965, 17003, 388677, 356263, 297249, 292428, 30992, 515785, 361382, 572462, 15029, 131115, 280079, 14226, 568107, 84000, 9927, 141416, 561223, 11300, 153971, 128748, 420234, 26617, 257046, 64531, 418535, 444755, 474344, 54516, 123137, 252220, 186711, 350167, 134198, 424642, 132931, 21900, 192670, 91052, 525354, 187533, 565761, 386677, 207458, 529670, 174603, 156704, 376449, 344125, 213695, 416596, 76170, 378347, 530875, 110617, 324891, 456521, 262594, 498915, 190841, 442019, 481239, 15818, 8191, 160456, 110597, 394206, 186856, 524844, 115772, 26512, 61722, 39858, 415723, 430961, 303101, 561810, 263083, 286313, 490381, 87681, 283264, 131494, 13985, 471073, 303024, 442582, 562243, 442136, 213171, 99518, 9800, 20276, 462931, 78707, 332058, 271997, 314074, 412399, 59744, 556130, 359126, 26907, 315448, 4438, 519055, 276719, 505400, 107234, 7593, 444955, 160864, 11316, 542605, 353593, 241882, 114481, 300408, 214742, 131804, 414821, 234526, 43693, 7816, 576652, 238228, 461838, 494855, 50767, 500478, 568981, 47394, 213586, 52624, 32645, 390348, 113890, 210457, 244665, 414917, 26802, 257657, 450559, 270215, 97423, 56504, 369511, 119911, 128654, 165419, 151138, 574135, 277422, 311015, 492840, 556545, 534827, 531350, 477853, 168248, 430054, 149115, 81860, 31106, 379667, 128142, 301755, 31093, 256031, 153229, 136833, 408449, 332869, 313955, 485917, 119547, 444491, 476894, 249301, 357816, 399666, 201326, 43625, 350884, 577398, 519631, 484614, 314026, 28881, 442463, 215439, 394050, 181836, 372494, 398045, 232160, 26209, 74369],
       'outdir': 'CAM/testing',
       'featuresplit': False, 
       'split': 1024,
       'coco2014_images': '/n/fs/visualai-scr/Data/Coco/2014data',
       'device': torch.device('cuda'),
       'dtype': torch.float32}
print(arg, '\n', flush=True)

normalize = T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
transform = T.Compose([
    T.Resize(224),
    T.CenterCrop(224),
    T.ToTensor()
])

coco = COCO('/n/fs/visualai-scr/Data/Coco/2014data/annotations/instances_val2014.json')
img_dir = '/n/fs/visualai-scr/Data/Coco/2014data/val2014'

classifier_features = []
def hook_classifier_features(module, input, output):
    classifier_features.append(output)

classifier = multilabel_classifier(device=arg['device'], dtype=arg['dtype'], modelpath=arg['modelpath'])
classifier.model = classifier.model.to(device=classifier.device, dtype=classifier.dtype)

classifier.model._modules['resnet'].layer4.register_forward_hook(hook_classifier_features)
classifier_params = list(classifier.model.parameters())
classifier_softmax_weight = classifier_params[-2].squeeze(0)

all_IOUS = []

for img_id in arg['img_ids']:
    # Open image                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
    img_path = '{}/train2014/COCO_train2014_{:012d}.jpg'.format(arg['coco2014_images'], img_id)
    img_name = img_path.split('/')[-1][:-4]
    if not os.path.exists(img_path):
        # Try searching in val set                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
        img_path = '{}/val2014/COCO_val2014_{:012d}.jpg'.format(arg['coco2014_images'], img_id)
        print('img_path: ', img_path)
        img_name = img_path.split('/')[-1][:-4]
        if not os.path.exists(img_path):
            print('WARNING: Could not find img {}'.format(img_id), flush=True)
            continue
    original_img = Image.open(img_path).convert('RGB')

    if arg['outdir'] != None:
        outdir = '{}/{}'.format(arg['outdir'], img_id)
    else:
        outdir = str(img_id)
    if not os.path.exists(outdir):
        os.makedirs(outdir)
    print('Processing img {}'.format(img_id), flush=True)

    # Get image class labels                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           
    img_labels = pickle.load(open('data/gender_labels_train.pkl', 'rb'))
    if img_path in img_labels:
        if torch.cuda.device_count() > 0:
            class_labels = img_labels[img_path].type('torch.cuda.ByteTensor')
        else:
            class_labels = img_labels[img_path].type('torch.ByteTensor')
    else:
        img_labels = pickle.load(open('data/gender_labels_test.pkl', 'rb'))
        if img_path in img_labels:
            if torch.cuda.device_count() > 0:
                class_labels = [img_labels[img_path]]
                #class_labels = img_labels[img_path].type('torch.cuda.ByteTensor')                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
            else:
                class_labels = [img_labels[img_path]]
                class_labels = img_labels[img_path].type('torch.ByteTensor')
        else:
            print('No labels found for image {}'.format(img_path), flush=True)
            class_labels = torch.zeros(1)
    #class_labels = torch.flatten(torch.nonzero(class_labels))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
    class_labels = torch.FloatTensor(class_labels)
    classifier_features.clear()
    img = transform(original_img)
    norm_img = normalize(img)
    norm_img = norm_img.to(device=classifier.device, dtype=classifier.dtype)
    norm_img = norm_img.unsqueeze(0)
    x = classifier.forward(norm_img)

    if arg['featuresplit']:
        CAMs = returnCAM_featuresplit(classifier_features[0], classifier_softmax_weight, class_labels, arg['device'], split=arg['split'])
    else:
        CAMs = returnCAM(classifier_features[0], classifier_softmax_weight, class_labels, arg['device'])
    CAMs = CAMs.detach().cpu().numpy()

    # Save CAM heatmap                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
    #humanlabels_to_onehot = pickle.load(open('/n/fs/context-scr/data/COCOStuff/humanlabels_to_onehot.pkl', 'rb'))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
    #onehot_to_humanlabels = {v: k for k,v in humanlabels_to_onehot.items()}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           
    onehot_to_humanlabels= {0: 'male',
                            1: 'female'}
    img = np.moveaxis(img.detach().cpu().numpy(), 0, -1)
    class_labels = class_labels.cpu().detach().numpy()
    for i in range(len(class_labels)):
        heatmap = get_heatmap(CAMs[i], img)
        image_id = img_id
        img = coco.imgs[image_id]
        gt_ann_ids = coco.getAnnIds(imgIds=[image_id])
        anns = coco.loadAnns(gt_ann_ids)

        mask = np.zeros(coco.annToMask(anns[0]).shape)
        for i in range(len(anns)):
            if anns[i]['category_id']==1:
                mask += coco.annToMask(anns[i])
                break

        person_seg_mask = np.squeeze(transform(Image.fromarray(mask)))
        INTERSECTION = np.sum(np.bitwise_and(np.array(person_seg_mask)>0, np.array(heatmap)>0))
        UNION = np.sum(np.bitwise_or(np.array(person_seg_mask)>0, np.array(heatmap)>0))
        IOU = INTERSECTION/UNION
        all_IOUS.append(IOU)
# Out:
# {'modelpath': '/n/fs/context-scr/nmeister/genderbias/models_new/224/lr_0.0001_wd_0.0/model_199.pth', 'img_ids': [373424, 297180, 3761, 416851, 133690, 541108, 16308, 32932, 386035, 446812, 89078, 416660, 147448, 350231, 516875, 351868, 186038, 62692, 300791, 395665, 445597, 279984, 508006, 279490, 297669, 407286, 391090, 384136, 201305, 284542, 554500, 1757, 428140, 321390, 44476, 300142, 459265, 303926, 97809, 457249, 356827, 312421, 31981, 163746, 499866, 37988, 48320, 164366, 182681, 552504, 457003, 431177, 255322, 7050, 364031, 169500, 135483, 343453, 507833, 170716, 229286, 36561, 259761, 100624, 522889, 89814, 320106, 580847, 40821, 218060, 46497, 537991, 303219, 325907, 393068, 185890, 478420, 456127, 366679, 120783, 548223, 114389, 81827, 304180, 92985, 443969, 13639, 336053, 419386, 210857, 311300, 193968, 278323, 140983, 422755, 156375, 484978, 489763, 53183, 427612, 321476, 479126, 536000, 557596, 4554, 487498, 489407, 202001, 138075, 445999, 414170, 433980, 134552, 194716, 41899, 25228, 487575, 542634, 300323, 347390, 558458, 227204, 117197, 548703, 161032, 526222, 278365, 334021, 519706, 520430, 310442, 192858, 382737, 70739, 316254, 264948, 385377, 415153, 410339, 124873, 374982, 221864, 452767, 331875, 393743, 280888, 230646, 283947, 231855, 248761, 79189, 185156, 157220, 577277, 563615, 161925, 323561, 16285, 463398, 84533, 52936, 580778, 191342, 475725, 507273, 200572, 558661, 168583, 277020, 443835, 15140, 428754, 193674, 82940, 142108, 524665, 338384, 446990, 18928, 233915, 377984, 333020, 547258, 179571, 230468, 526000, 383419, 248069, 327617, 473237, 63939, 399462, 235808, 266889, 3934, 488500, 261587, 516416, 376891, 276055, 348973, 37865, 342204, 135756, 266768, 455355, 351489, 280909, 545735, 191577, 549797, 267315, 198448, 3786, 143119, 167724, 441511, 407644, 29045, 496718, 389273, 21924, 332844, 114710, 143926, 295957, 419190, 412247, 27731, 556862, 530061, 367804, 564612, 505471, 447787, 381608, 367818, 533976, 18563, 359947, 204059, 281759, 470536, 365851, 178753, 54654, 237428, 453001, 496239, 124629, 470545, 191721, 550117, 419158, 513965, 71072, 175908, 385320, 225963, 190372, 47739, 227491, 434657, 223362, 154644, 462345, 510548, 209995, 506874, 144243, 355179, 562885, 421915, 350002, 87864, 58350, 413634, 543193, 187658, 519688, 301266, 362869, 1296, 531967, 162530, 75187, 580108, 73753, 26560, 399415, 246968, 456662, 335532, 242724, 253986, 254164, 19032, 47624, 490923, 385861, 107729, 213247, 262235, 192838, 170173, 59207, 267314, 576629, 542758, 24243, 61747, 139856, 328728, 376247, 555669, 562150, 508339, 470604, 30066, 375021, 230245, 494014, 402233, 520778, 490582, 402823, 149592, 397225, 29934, 132544, 168781, 437351, 177934, 392022, 65736, 285291, 45627, 407602, 431173, 9813, 439902, 253960, 117744, 511463, 449522, 437325, 232610, 132554, 515485, 263613, 231879, 294621, 371289, 147482, 419453, 31164, 45835, 252091, 390585, 84866, 169547, 233124, 27221, 64462, 96785, 169198, 487435, 548337, 580294, 405444, 693, 96215, 182025, 194158, 366031, 48684, 553869, 386879, 22801, 80306, 200471, 264568, 487418, 533449, 530934, 496548, 212558, 172946, 249687, 344005, 363036, 8690, 383838, 522425, 195842, 58425, 309418, 122678, 66336, 114183, 549713, 516345, 486175, 321968, 373344, 406147, 126512, 113159, 355197, 425136, 337264, 32081, 4980, 198489, 273967, 265125, 503755, 215787, 359589, 536653, 502570, 213421, 569314, 66502, 528046, 161781, 151965, 246746, 187743, 265777, 37158, 561539, 410337, 1180, 217522, 306670, 289900, 113037, 511669, 358572], 'outdir': 'CAM/testing', 'featuresplit': False, 'split': 1024, 'coco2014_images': '/n/fs/visualai-scr/Data/Coco/2014data', 'device': device(type='cuda'), 'dtype': torch.float32}
#
# loading annotations into memory...
# Done (t=6.18s)
# creating index...
# index created!
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000373424.jpg
# Processing img 373424
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000297180.jpg
# Processing img 297180
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000003761.jpg
# Processing img 3761
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000416851.jpg
# Processing img 416851
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000133690.jpg
# Processing img 133690
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000541108.jpg
# Processing img 541108
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000016308.jpg
# Processing img 16308
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000032932.jpg
# Processing img 32932
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000386035.jpg
# Processing img 386035
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000446812.jpg
# Processing img 446812
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000089078.jpg
# Processing img 89078
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000416660.jpg
# Processing img 416660
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000147448.jpg
# Processing img 147448
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000350231.jpg
# Processing img 350231
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000516875.jpg
# Processing img 516875
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000351868.jpg
# Processing img 351868
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000186038.jpg
# Processing img 186038
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000062692.jpg
# Processing img 62692
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000300791.jpg
# Processing img 300791
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000395665.jpg
# Processing img 395665
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000445597.jpg
# Processing img 445597
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000279984.jpg
# Processing img 279984
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000508006.jpg
# Processing img 508006
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000279490.jpg
# Processing img 279490
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000297669.jpg
# Processing img 297669
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000407286.jpg
# Processing img 407286
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000391090.jpg
# Processing img 391090
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000384136.jpg
# Processing img 384136
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000201305.jpg
# Processing img 201305
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000284542.jpg
# Processing img 284542
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000554500.jpg
# Processing img 554500
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000001757.jpg
# Processing img 1757
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000428140.jpg
# Processing img 428140
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000321390.jpg
# Processing img 321390
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000044476.jpg
# Processing img 44476
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000300142.jpg
# Processing img 300142
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000459265.jpg
# Processing img 459265
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000303926.jpg
# Processing img 303926
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000097809.jpg
# Processing img 97809
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000457249.jpg
# Processing img 457249
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000356827.jpg
# Processing img 356827
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000312421.jpg
# Processing img 312421
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000031981.jpg
# Processing img 31981
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000163746.jpg
# Processing img 163746
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000499866.jpg
# Processing img 499866
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000037988.jpg
# Processing img 37988
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000048320.jpg
# Processing img 48320
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000164366.jpg
# Processing img 164366
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000182681.jpg
# Processing img 182681
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000552504.jpg
# Processing img 552504
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000457003.jpg
# Processing img 457003
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000431177.jpg
# Processing img 431177
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000255322.jpg
# Processing img 255322
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000007050.jpg
# Processing img 7050
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000364031.jpg
# Processing img 364031
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000169500.jpg
# Processing img 169500
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000135483.jpg
# Processing img 135483
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000343453.jpg
# Processing img 343453
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000507833.jpg
# Processing img 507833
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000170716.jpg
# Processing img 170716
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000229286.jpg
# Processing img 229286
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000036561.jpg
# Processing img 36561
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000259761.jpg
# Processing img 259761
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000100624.jpg
# Processing img 100624
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000522889.jpg
# Processing img 522889
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000089814.jpg
# Processing img 89814
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000320106.jpg
# Processing img 320106
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000580847.jpg
# Processing img 580847
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000040821.jpg
# Processing img 40821
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000218060.jpg
# Processing img 218060
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000046497.jpg
# Processing img 46497
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000537991.jpg
# Processing img 537991
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000303219.jpg
# Processing img 303219
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000325907.jpg
# Processing img 325907
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000393068.jpg
# Processing img 393068
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000185890.jpg
# Processing img 185890
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000478420.jpg
# Processing img 478420
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000456127.jpg
# Processing img 456127
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000366679.jpg
# Processing img 366679
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000120783.jpg
# Processing img 120783
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000548223.jpg
# Processing img 548223
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000114389.jpg
# Processing img 114389
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000081827.jpg
# Processing img 81827
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000304180.jpg
# Processing img 304180
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000092985.jpg
# Processing img 92985
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000443969.jpg
# Processing img 443969
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000013639.jpg
# Processing img 13639
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000336053.jpg
# Processing img 336053
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000419386.jpg
# Processing img 419386
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000210857.jpg
# Processing img 210857
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000311300.jpg
# Processing img 311300
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000193968.jpg
# Processing img 193968
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000278323.jpg
# Processing img 278323
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000140983.jpg
# Processing img 140983
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000422755.jpg
# Processing img 422755
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000156375.jpg
# Processing img 156375
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000484978.jpg
# Processing img 484978
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000489763.jpg
# Processing img 489763
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000053183.jpg
# Processing img 53183
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000427612.jpg
# Processing img 427612
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000321476.jpg
# Processing img 321476
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000479126.jpg
# Processing img 479126
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000536000.jpg
# Processing img 536000
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000557596.jpg
# Processing img 557596
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000004554.jpg
# Processing img 4554
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000487498.jpg
# Processing img 487498
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000489407.jpg
# Processing img 489407
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000202001.jpg
# Processing img 202001
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000138075.jpg
# Processing img 138075
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000445999.jpg
# Processing img 445999
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000414170.jpg
# Processing img 414170
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000433980.jpg
# Processing img 433980
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000134552.jpg
# Processing img 134552
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000194716.jpg
# Processing img 194716
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000041899.jpg
# Processing img 41899
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000025228.jpg
# Processing img 25228
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000487575.jpg
# Processing img 487575
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000542634.jpg
# Processing img 542634
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000300323.jpg
# Processing img 300323
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000347390.jpg
# Processing img 347390
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000558458.jpg
# Processing img 558458
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000227204.jpg
# Processing img 227204
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000117197.jpg
# Processing img 117197
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000548703.jpg
# Processing img 548703
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000161032.jpg
# Processing img 161032
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000526222.jpg
# Processing img 526222
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000278365.jpg
# Processing img 278365
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000334021.jpg
# Processing img 334021
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000519706.jpg
# Processing img 519706
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000520430.jpg
# Processing img 520430
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000310442.jpg
# Processing img 310442
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000192858.jpg
# Processing img 192858
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000382737.jpg
# Processing img 382737
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000070739.jpg
# Processing img 70739
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000316254.jpg
# Processing img 316254
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000264948.jpg
# Processing img 264948
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000385377.jpg
# Processing img 385377
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000415153.jpg
# Processing img 415153
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000410339.jpg
# Processing img 410339
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000124873.jpg
# Processing img 124873
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000374982.jpg
# Processing img 374982
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000221864.jpg
# Processing img 221864
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000452767.jpg
# Processing img 452767
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000331875.jpg
# Processing img 331875
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000393743.jpg
# Processing img 393743
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000280888.jpg
# Processing img 280888
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000230646.jpg
# Processing img 230646
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000283947.jpg
# Processing img 283947
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000231855.jpg
# Processing img 231855
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000248761.jpg
# Processing img 248761
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000079189.jpg
# Processing img 79189
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000185156.jpg
# Processing img 185156
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000157220.jpg
# Processing img 157220
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000577277.jpg
# Processing img 577277
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000563615.jpg
# Processing img 563615
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000161925.jpg
# Processing img 161925
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000323561.jpg
# Processing img 323561
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000016285.jpg
# Processing img 16285
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000463398.jpg
# Processing img 463398
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000084533.jpg
# Processing img 84533
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000052936.jpg
# Processing img 52936
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000580778.jpg
# Processing img 580778
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000191342.jpg
# Processing img 191342
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000475725.jpg
# Processing img 475725
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000507273.jpg
# Processing img 507273
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000200572.jpg
# Processing img 200572
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000558661.jpg
# Processing img 558661
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000168583.jpg
# Processing img 168583
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000277020.jpg
# Processing img 277020
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000443835.jpg
# Processing img 443835
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000015140.jpg
# Processing img 15140
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000428754.jpg
# Processing img 428754
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000193674.jpg
# Processing img 193674
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000082940.jpg
# Processing img 82940
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000142108.jpg
# Processing img 142108
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000524665.jpg
# Processing img 524665
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000338384.jpg
# Processing img 338384
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000446990.jpg
# Processing img 446990
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000018928.jpg
# Processing img 18928
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000233915.jpg
# Processing img 233915
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000377984.jpg
# Processing img 377984
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000333020.jpg
# Processing img 333020
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000547258.jpg
# Processing img 547258
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000179571.jpg
# Processing img 179571
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000230468.jpg
# Processing img 230468
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000526000.jpg
# Processing img 526000
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000383419.jpg
# Processing img 383419
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000248069.jpg
# Processing img 248069
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000327617.jpg
# Processing img 327617
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000473237.jpg
# Processing img 473237
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000063939.jpg
# Processing img 63939
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000399462.jpg
# Processing img 399462
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000235808.jpg
# Processing img 235808
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000266889.jpg
# Processing img 266889
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000003934.jpg
# Processing img 3934
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000488500.jpg
# Processing img 488500
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000261587.jpg
# Processing img 261587
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000516416.jpg
# Processing img 516416
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000376891.jpg
# Processing img 376891
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000276055.jpg
# Processing img 276055
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000348973.jpg
# Processing img 348973
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000037865.jpg
# Processing img 37865
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000342204.jpg
# Processing img 342204
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000135756.jpg
# Processing img 135756
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000266768.jpg
# Processing img 266768
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000455355.jpg
# Processing img 455355
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000351489.jpg
# Processing img 351489
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000280909.jpg
# Processing img 280909
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000545735.jpg
# Processing img 545735
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000191577.jpg
# Processing img 191577
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000549797.jpg
# Processing img 549797
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000267315.jpg
# Processing img 267315
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000198448.jpg
# Processing img 198448
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000003786.jpg
# Processing img 3786
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000143119.jpg
# Processing img 143119
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000167724.jpg
# Processing img 167724
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000441511.jpg
# Processing img 441511
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000407644.jpg
# Processing img 407644
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000029045.jpg
# Processing img 29045
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000496718.jpg
# Processing img 496718
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000389273.jpg
# Processing img 389273
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000021924.jpg
# Processing img 21924
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000332844.jpg
# Processing img 332844
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000114710.jpg
# Processing img 114710
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000143926.jpg
# Processing img 143926
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000295957.jpg
# Processing img 295957
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000419190.jpg
# Processing img 419190
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000412247.jpg
# Processing img 412247
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000027731.jpg
# Processing img 27731
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000556862.jpg
# Processing img 556862
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000530061.jpg
# Processing img 530061
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000367804.jpg
# Processing img 367804
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000564612.jpg
# Processing img 564612
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000505471.jpg
# Processing img 505471
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000447787.jpg
# Processing img 447787
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000381608.jpg
# Processing img 381608
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000367818.jpg
# Processing img 367818
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000533976.jpg
# Processing img 533976
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000018563.jpg
# Processing img 18563
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000359947.jpg
# Processing img 359947
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000204059.jpg
# Processing img 204059
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000281759.jpg
# Processing img 281759
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000470536.jpg
# Processing img 470536
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000365851.jpg
# Processing img 365851
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000178753.jpg
# Processing img 178753
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000054654.jpg
# Processing img 54654
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000237428.jpg
# Processing img 237428
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000453001.jpg
# Processing img 453001
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000496239.jpg
# Processing img 496239
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000124629.jpg
# Processing img 124629
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000470545.jpg
# Processing img 470545
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000191721.jpg
# Processing img 191721
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000550117.jpg
# Processing img 550117
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000419158.jpg
# Processing img 419158
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000513965.jpg
# Processing img 513965
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000071072.jpg
# Processing img 71072
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000175908.jpg
# Processing img 175908
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000385320.jpg
# Processing img 385320
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000225963.jpg
# Processing img 225963
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000190372.jpg
# Processing img 190372
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000047739.jpg
# Processing img 47739
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000227491.jpg
# Processing img 227491
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000434657.jpg
# Processing img 434657
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000223362.jpg
# Processing img 223362
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000154644.jpg
# Processing img 154644
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000462345.jpg
# Processing img 462345
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000510548.jpg
# Processing img 510548
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000209995.jpg
# Processing img 209995
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000506874.jpg
# Processing img 506874
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000144243.jpg
# Processing img 144243
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000355179.jpg
# Processing img 355179
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000562885.jpg
# Processing img 562885
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000421915.jpg
# Processing img 421915
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000350002.jpg
# Processing img 350002
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000087864.jpg
# Processing img 87864
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000058350.jpg
# Processing img 58350
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000413634.jpg
# Processing img 413634
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000543193.jpg
# Processing img 543193
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000187658.jpg
# Processing img 187658
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000519688.jpg
# Processing img 519688
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000301266.jpg
# Processing img 301266
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000362869.jpg
# Processing img 362869
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000001296.jpg
# Processing img 1296
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000531967.jpg
# Processing img 531967
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000162530.jpg
# Processing img 162530
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000075187.jpg
# Processing img 75187
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000580108.jpg
# Processing img 580108
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000073753.jpg
# Processing img 73753
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000026560.jpg
# Processing img 26560
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000399415.jpg
# Processing img 399415
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000246968.jpg
# Processing img 246968
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000456662.jpg
# Processing img 456662
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000335532.jpg
# Processing img 335532
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000242724.jpg
# Processing img 242724
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000253986.jpg
# Processing img 253986
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000254164.jpg
# Processing img 254164
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000019032.jpg
# Processing img 19032
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000047624.jpg
# Processing img 47624
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000490923.jpg
# Processing img 490923
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000385861.jpg
# Processing img 385861
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000107729.jpg
# Processing img 107729
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000213247.jpg
# Processing img 213247
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000262235.jpg
# Processing img 262235
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000192838.jpg
# Processing img 192838
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000170173.jpg
# Processing img 170173
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000059207.jpg
# Processing img 59207
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000267314.jpg
# Processing img 267314
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000576629.jpg
# Processing img 576629
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000542758.jpg
# Processing img 542758
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000024243.jpg
# Processing img 24243
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000061747.jpg
# Processing img 61747
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000139856.jpg
# Processing img 139856
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000328728.jpg
# Processing img 328728
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000376247.jpg
# Processing img 376247
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000555669.jpg
# Processing img 555669
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000562150.jpg
# Processing img 562150
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000508339.jpg
# Processing img 508339
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000470604.jpg
# Processing img 470604
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000030066.jpg
# Processing img 30066
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000375021.jpg
# Processing img 375021
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000230245.jpg
# Processing img 230245
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000494014.jpg
# Processing img 494014
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000402233.jpg
# Processing img 402233
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000520778.jpg
# Processing img 520778
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000490582.jpg
# Processing img 490582
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000402823.jpg
# Processing img 402823
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000149592.jpg
# Processing img 149592
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000397225.jpg
# Processing img 397225
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000029934.jpg
# Processing img 29934
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000132544.jpg
# Processing img 132544
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000168781.jpg
# Processing img 168781
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000437351.jpg
# Processing img 437351
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000177934.jpg
# Processing img 177934
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000392022.jpg
# Processing img 392022
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000065736.jpg
# Processing img 65736
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000285291.jpg
# Processing img 285291
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000045627.jpg
# Processing img 45627
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000407602.jpg
# Processing img 407602
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000431173.jpg
# Processing img 431173
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000009813.jpg
# Processing img 9813
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000439902.jpg
# Processing img 439902
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000253960.jpg
# Processing img 253960
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000117744.jpg
# Processing img 117744
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000511463.jpg
# Processing img 511463
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000449522.jpg
# Processing img 449522
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000437325.jpg
# Processing img 437325
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000232610.jpg
# Processing img 232610
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000132554.jpg
# Processing img 132554
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000515485.jpg
# Processing img 515485
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000263613.jpg
# Processing img 263613
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000231879.jpg
# Processing img 231879
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000294621.jpg
# Processing img 294621
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000371289.jpg
# Processing img 371289
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000147482.jpg
# Processing img 147482
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000419453.jpg
# Processing img 419453
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000031164.jpg
# Processing img 31164
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000045835.jpg
# Processing img 45835
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000252091.jpg
# Processing img 252091
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000390585.jpg
# Processing img 390585
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000084866.jpg
# Processing img 84866
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000169547.jpg
# Processing img 169547
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000233124.jpg
# Processing img 233124
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000027221.jpg
# Processing img 27221
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000064462.jpg
# Processing img 64462
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000096785.jpg
# Processing img 96785
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000169198.jpg
# Processing img 169198
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000487435.jpg
# Processing img 487435
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000548337.jpg
# Processing img 548337
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000580294.jpg
# Processing img 580294
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000405444.jpg
# Processing img 405444
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000000693.jpg
# Processing img 693
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000096215.jpg
# Processing img 96215
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000182025.jpg
# Processing img 182025
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000194158.jpg
# Processing img 194158
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000366031.jpg
# Processing img 366031
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000048684.jpg
# Processing img 48684
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000553869.jpg
# Processing img 553869
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000386879.jpg
# Processing img 386879
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000022801.jpg
# Processing img 22801
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000080306.jpg
# Processing img 80306
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000200471.jpg
# Processing img 200471
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000264568.jpg
# Processing img 264568
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000487418.jpg
# Processing img 487418
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000533449.jpg
# Processing img 533449
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000530934.jpg
# Processing img 530934
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000496548.jpg
# Processing img 496548
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000212558.jpg
# Processing img 212558
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000172946.jpg
# Processing img 172946
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000249687.jpg
# Processing img 249687
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000344005.jpg
# Processing img 344005
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000363036.jpg
# Processing img 363036
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000008690.jpg
# Processing img 8690
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000383838.jpg
# Processing img 383838
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000522425.jpg
# Processing img 522425
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000195842.jpg
# Processing img 195842
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000058425.jpg
# Processing img 58425
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000309418.jpg
# Processing img 309418
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000122678.jpg
# Processing img 122678
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000066336.jpg
# Processing img 66336
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000114183.jpg
# Processing img 114183
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000549713.jpg
# Processing img 549713
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000516345.jpg
# Processing img 516345
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000486175.jpg
# Processing img 486175
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000321968.jpg
# Processing img 321968
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000373344.jpg
# Processing img 373344
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000406147.jpg
# Processing img 406147
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000126512.jpg
# Processing img 126512
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000113159.jpg
# Processing img 113159
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000355197.jpg
# Processing img 355197
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000425136.jpg
# Processing img 425136
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000337264.jpg
# Processing img 337264
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000032081.jpg
# Processing img 32081
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000004980.jpg
# Processing img 4980
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000198489.jpg
# Processing img 198489
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000273967.jpg
# Processing img 273967
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000265125.jpg
# Processing img 265125
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000503755.jpg
# Processing img 503755
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000215787.jpg
# Processing img 215787
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000359589.jpg
# Processing img 359589
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000536653.jpg
# Processing img 536653
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000502570.jpg
# Processing img 502570
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000213421.jpg
# Processing img 213421
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000569314.jpg
# Processing img 569314
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000066502.jpg
# Processing img 66502
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000528046.jpg
# Processing img 528046
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000161781.jpg
# Processing img 161781
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000151965.jpg
# Processing img 151965
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000246746.jpg
# Processing img 246746
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000187743.jpg
# Processing img 187743
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000265777.jpg
# Processing img 265777
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000037158.jpg
# Processing img 37158
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000561539.jpg
# Processing img 561539
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000410337.jpg
# Processing img 410337
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000001180.jpg
# Processing img 1180
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000217522.jpg
# Processing img 217522
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000306670.jpg
# Processing img 306670
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000289900.jpg
# Processing img 289900
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000113037.jpg
# Processing img 113037
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000511669.jpg
# Processing img 511669
# img_path:  /n/fs/visualai-scr/Data/Coco/2014data/val2014/COCO_val2014_000000358572.jpg
# Processing img 358572

# %%
import copy

# %%
F_NTop10 = copy.deepcopy(all_IOUS)
np.average(F_NTop10)
# Out:
# 0.20807955625835364

# %%
M_NTop10 = copy.deepcopy(all_IOUS)
np.average(M_NTop10)
# Out:
# 0.1422955357266639

# %%
F_Top10 = copy.deepcopy(all_IOUS)
np.average(F_Top10)
# Out:
# 0.20897014707848152

# %%
M_Top10 = copy.deepcopy(all_IOUS)
np.average(M_Top10)
# Out:
# 0.12255045468406126

# %% [markdown]
# Distribution

# %%
ALL_F = F_NTop10 + F_Top10
ALL_M = M_NTop10 + M_Top10

# %%
print("Female No Top 10 ----- Average: {:.3f} Std Dev: {:.3f}".format(np.average(F_NTop10), np.std(F_NTop10)))
print("Male No Top 10 ----- Average: {:.3f} Std Dev: {:.3f}".format(np.average(M_NTop10), np.std(M_NTop10)))
print("Female Top 10 ----- Average: {:.3f} Std Dev: {:.3f}".format(np.average(F_Top10), np.std(F_Top10)))
print("Male Top 10 ----- Average: {:.3f} Std Dev: {:.3f}".format(np.average(M_Top10), np.std(M_Top10)))
print("ALL Female Top 10 ----- Average: {:.3f} Std Dev: {:.3f}".format(np.average(ALL_F), np.std(ALL_F)))
print("ALL Male Top 10 ----- Average: {:.3f} Std Dev: {:.3f}".format(np.average(ALL_M), np.std(ALL_M)))
print("ALL Top 10 ----- Average: {:.3f} Std Dev: {:.3f}".format(np.average(ALL_M+ALL_F), np.std(ALL_M+ALL_F)))
# Out:
# Female No Top 10 ----- Average: 0.208 Std Dev: 0.152
# Male No Top 10 ----- Average: 0.142 Std Dev: 0.135
# Female Top 10 ----- Average: 0.209 Std Dev: 0.164
# Male Top 10 ----- Average: 0.123 Std Dev: 0.126
# ALL Female Top 10 ----- Average: 0.208 Std Dev: 0.156
# ALL Male Top 10 ----- Average: 0.134 Std Dev: 0.132
# ALL Top 10 ----- Average: 0.156 Std Dev: 0.143

# %% [markdown]
# Statistical Test

# %%
from scipy.stats import ttest_ind
print('All F vs All M: ', ttest_ind(ALL_F, ALL_M))
# Compare no top 10 vs top 10 objects in Female and Male
print('No Top 10 F vs Top 10 F: ', ttest_ind(F_NTop10, F_Top10))
print('No Top 10 M vs Top 10 M: ', ttest_ind(M_NTop10, M_Top10))

# Compare Female vs Male in Top 10 vs No Top 10
print('No Top 10 F vs No Top 10 M: ', ttest_ind(F_NTop10, M_NTop10))
print('Top 10 F vs Top 10 M: ', ttest_ind(F_Top10, M_Top10))
# Out:
# All F vs All M:  Ttest_indResult(statistic=11.345362040042433, pvalue=5.11743645709077e-29)
# No Top 10 F vs Top 10 F:  Ttest_indResult(statistic=-0.06636889552170158, pvalue=0.9471050562516303)
# No Top 10 M vs Top 10 M:  Ttest_indResult(statistic=2.9048697467281706, pvalue=0.0037272541379607025)
# No Top 10 F vs No Top 10 M:  Ttest_indResult(statistic=7.938015058909909, pvalue=4.422356186554228e-15)
# Top 10 F vs Top 10 M:  Ttest_indResult(statistic=7.814585267414432, pvalue=1.610532700862845e-14)

# %%
plt.imshow(img)
plt.imshow(heatmap, cmap='jet', alpha=0.5)
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-be33d973a2cc> in <module>
# ----> 1 plt.imshow(img)
#       2 plt.imshow(heatmap, cmap='jet', alpha=0.5)
#       3 plt.axis('off')
#
# /n/fs/context-scr/anaconda/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /n/fs/context-scr/anaconda/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /n/fs/context-scr/anaconda/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# /n/fs/context-scr/anaconda/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     700         if (self._A.dtype != np.uint8 and
#     701                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 702             raise TypeError("Image data of dtype {} cannot be converted to "
#     703                             "float".format(self._A.dtype))
#     704
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
coco = COCO('/n/fs/visualai-scr/Data/Coco/2014data/annotations/instances_val2014.json')
img_dir = '/n/fs/visualai-scr/Data/Coco/2014data/val2014'
image_id = 242365
gt_ann_ids = coco.getAnnIds(imgIds=[image_id])
anns = coco.loadAnns(gt_ann_ids)

img = coco.imgs[image_id]

mask = np.zeros(coco.annToMask(anns[1]).shape)
for i in range(len(anns)):
    if anns[i]['category_id']==1:
        mask += coco.annToMask(anns[i])

person_seg_mask = np.squeeze(transform(Image.fromarray(mask)))

#and 
INTERSECTION = np.sum(np.bitwise_and(np.array(person_seg_mask)>0, np.array(heatmap)>0))
# or 
UNION = np.sum(np.bitwise_or(np.array(person_seg_mask)>0, np.array(heatmap)>0))
IOU = INTERSECTION/UNION
print(IOU)
# Out:
# loading annotations into memory...
# Done (t=5.84s)
# creating index...
# index created!
# 0.15600816232241174

# %%
plt.imshow(np.bitwise_and(np.array(person_seg_mask)>0, np.array(heatmap)>0))

# %%
plt.imshow(np.bitwise_or(np.array(person_seg_mask)>0, np.array(heatmap)>0))

# %%
plt.imshow(heatmap)
plt.imshow(person_seg_mask)

# %%
coco = COCO('/n/fs/visualai-scr/Data/Coco/2014data/annotations/instances_val2014.json')
img_dir = '/n/fs/visualai-scr/Data/Coco/2014data/val2014'
image_id = 242365
img = coco.imgs[image_id]
# Out:
# loading annotations into memory...
# Done (t=5.73s)
# creating index...
# index created!

# %%
mask = np.zeros(coco.annToMask(anns[1]).shape)
for i in range(len(anns)):
    if anns[i]['category_id']==1:
        mask += coco.annToMask(anns[i])


plt.imshow(np.squeeze(transform(Image.fromarray(mask))))
plt.axis('off')
# Out:
# (-0.5, 223.5, 223.5, -0.5)

# %%
person_seg_mask = np.squeeze(transform(Image.fromarray(mask)))
plt.imshow(person_seg_mask)

# %%
#and 
np.sum(np.bitwise_and(np.array(person_seg_mask)>0, np.array(heatmap)>0))
# or 
np.sum(np.bitwise_or(np.array(person_seg_mask)>0, np.array(heatmap)>0))
# Out:
# (4052, 25973)
